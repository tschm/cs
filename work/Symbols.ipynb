# %%
import pandas as pd

# %%
# We have picked a list of 49 futures...

# %%
pd.read_csv("symbols/symbols.csv").sort_values(by="Sector").reset_index(drop=True)
# Out:
#                            Description   Bloomberg         Sector  \
# 0                    Cotton #2 Futures  CT1 Comdty    Agriculture
# 1                   Coffee “C” Futures  KC1 Comdty    Agriculture
# 2                  Live Cattle Futures  LC1 Comdty    Agriculture
# 3                    Lean Hogs Futures  LH1 Comdty    Agriculture
# 4                Feeder Cattle Futures  FC1 Comdty    Agriculture
# 5                         Oats Futures  O 1 Comdty    Agriculture
# 6                 Orange Juice Futures  JO1 Comdty    Agriculture
# 7                         Corn Futures  C 1 Comdty    Agriculture
# 8                   Wheat Futures CBOT  W 1 Comdty    Agriculture
# 9                    Sugar #11 Futures  SB1 Comdty    Agriculture
# 10                       Cocoa Futures  CC1 Comdty    Agriculture
# 11                Soybean Meal Futures  SM1 Comdty    Agriculture
# 12                 Soybean Oil Futures  BO1 Comdty    Agriculture
# 13                     Soybean Futures  S 1 Comdty    Agriculture
# 14             Canadian Dollar Futures  CD1 Curncy       Currency
# 15          New Zealand Dollar Futures  NV1 Curncy       Currency
# 16                Mexican Peso Futures  PE1 Curncy       Currency
# 17               British Pound Futures  BP1 Curncy       Currency
# 18          Euro/British Pound Futures  RP1 Curncy       Currency
# 19           Australian Dollar Futures  AD1 Curncy       Currency
# 20      Crude Oil E-Mini Futures NYMEX  EC1 Comdty         Energy
# 21          Natural Gas E-Mini Futures  EO1 Comdty         Energy
# 22           Natural Gas Futures NYMEX  NG1 Comdty         Energy
# 23        Heating Oil #2 Futures NYMEX  HO1 Comdty         Energy
# 24      Low Sulphur Gasoil Futures ICE  QS1 Comdty         Energy
# 25       Light Crude Oil Futures NYMEX  CL1 Comdty         Energy
# 26         Brent Crude Oil Futures ICE  CO1 Comdty         Energy
# 27       STOXX Europe 50 Index Futures   VH1 Index   Equity Index
# 28                     S&P 500 Futures   SP1 Index   Equity Index
# 29                CAC 40 Index Futures   CF1 Index   Equity Index
# 30                   DAX Index Futures   GX1 Index   Equity Index
# 31  MSCI Emerging Markets Mini Futures  MES1 Index   Equity Index
# 32         EURO STOXX 50 Index Futures   VG1 Index   Equity Index
# 33         Amsterdam AEX Index Futures   EO1 Index   Equity Index
# 34       S&P 400 MidCap E-Mini Futures   FA1 Index   Equity Index
# 35              S&P 500 E-Mini Futures   ES1 Index   Equity Index
# 36              FTSE 100 Index Futures   Z 1 Index   Equity Index
# 37              Nikkei 225 Futures CME   NX1 Index   Equity Index
# 38             Eurodollar  Futures CME  ED1 Comdty  Interest Rate
# 39            US 5-Year T-Note Futures  FV1 Comdty  Interest Rate
# 40          Euro-Schatz 2-Year Futures  DU1 Comdty  Interest Rate
# 41           Euro-Bund 10-Year Futures  RX1 Comdty  Interest Rate
# 42             Euribor 3-Month Futures  ER1 Comdty  Interest Rate
# 43                   Long Gilt Futures  G 1 Comdty  Interest Rate
# 44             Palladium Futures NYMEX  PA1 Comdty         Metals
# 45     Copper High Grade Futures COMEX  HG1 Comdty         Metals
# 46                  Gold Futures COMEX  GC1 Comdty         Metals
# 47                Silver Futures COMEX  SI1 Comdty         Metals
# 48              Platinum Futures NYMEX  PL1 Comdty         Metals
#
#                           Exchange
# 0             ICE Futures US Softs
# 1             ICE Futures US Softs
# 2      Chicago Mercantile Exchange
# 3      Chicago Mercantile Exchange
# 4      Chicago Mercantile Exchange
# 5           Chicago Board of Trade
# 6             ICE Futures US Softs
# 7           Chicago Board of Trade
# 8           Chicago Board of Trade
# 9             ICE Futures US Softs
# 10            ICE Futures US Softs
# 11          Chicago Board of Trade
# 12          Chicago Board of Trade
# 13          Chicago Board of Trade
# 14     Chicago Mercantile Exchange
# 15     Chicago Mercantile Exchange
# 16     Chicago Mercantile Exchange
# 17     Chicago Mercantile Exchange
# 18     Chicago Mercantile Exchange
# 19     Chicago Mercantile Exchange
# 20    New York Mercantile Exchange
# 21    New York Mercantile Exchange
# 22    New York Mercantile Exchange
# 23    New York Mercantile Exchange
# 24  ICE Futures Europe Commodities
# 25    New York Mercantile Exchange
# 26  ICE Futures Europe Commodities
# 27                           Eurex
# 28     Chicago Mercantile Exchange
# 29      Euronext Derivatives Paris
# 30                           Eurex
# 31          ICE Futures US Indices
# 32                           Eurex
# 33  Euronext Derivatives Amsterdam
# 34     Chicago Mercantile Exchange
# 35     Chicago Mercantile Exchange
# 36   ICE Futures Europe Financials
# 37     Chicago Mercantile Exchange
# 38     Chicago Mercantile Exchange
# 39          Chicago Board of Trade
# 40                           Eurex
# 41                           Eurex
# 42   ICE Futures Europe Financials
# 43   ICE Futures Europe Financials
# 44    New York Mercantile Exchange
# 45         Commodity Exchange Inc.
# 46         Commodity Exchange Inc.
# 47         Commodity Exchange Inc.
# 48    New York Mercantile Exchange

# %%
pd.read_csv("data/prices.csv", index_col=0)
